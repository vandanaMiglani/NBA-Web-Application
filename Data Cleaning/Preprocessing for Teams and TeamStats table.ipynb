# %%
import pandas as pd

# %%
teams_df = pd.read_csv('/content/teams.csv')
teams_df
# Out:
#     LEAGUE_ID     TEAM_ID  ...         HEADCOACH                 DLEAGUEAFFILIATION
# 0           0  1610612737  ...      Lloyd Pierce                      Erie Bayhawks
# 1           0  1610612738  ...      Brad Stevens                    Maine Red Claws
# 2           0  1610612740  ...      Alvin Gentry                       No Affiliate
# 3           0  1610612741  ...        Jim Boylen                   Windy City Bulls
# 4           0  1610612742  ...     Rick Carlisle                      Texas Legends
# 5           0  1610612743  ...    Michael Malone                       No Affiliate
# 6           0  1610612745  ...     Mike D'Antoni           Rio Grande Valley Vipers
# 7           0  1610612746  ...        Doc Rivers  Agua Caliente Clippers of Ontario
# 8           0  1610612747  ...       Frank Vogel                   South Bay Lakers
# 9           0  1610612748  ...    Erik Spoelstra               Sioux Falls Skyforce
# ...

# %%
teams_df.shape
# Out:
# (30, 14)

# %%
teams_df.columns
# Out:
# Index(['LEAGUE_ID', 'TEAM_ID', 'MIN_YEAR', 'MAX_YEAR', 'ABBREVIATION',
#        'NICKNAME', 'YEARFOUNDED', 'CITY', 'ARENA', 'ARENACAPACITY', 'OWNER',
#        'GENERALMANAGER', 'HEADCOACH', 'DLEAGUEAFFILIATION'],
#       dtype='object')

# %%
teams_df['Team_Name'] = teams_df['CITY'] +" "+ teams_df['NICKNAME']
teams_df['Team_Name']
# Out:
# 0              Atlanta Hawks
# 1             Boston Celtics
# 2       New Orleans Pelicans
# 3              Chicago Bulls
# 4           Dallas Mavericks
# 5             Denver Nuggets
# 6            Houston Rockets
# 7       Los Angeles Clippers
# 8         Los Angeles Lakers
# 9                 Miami Heat
# 10           Milwaukee Bucks
# 11    Minnesota Timberwolves
# 12             Brooklyn Nets
# 13           New York Knicks
# 14             Orlando Magic
# 15            Indiana Pacers
# 16        Philadelphia 76ers
# 17              Phoenix Suns
# 18    Portland Trail Blazers
# 19          Sacramento Kings
# 20         San Antonio Spurs
# 21     Oklahoma City Thunder
# 22           Toronto Raptors
# 23                 Utah Jazz
# 24         Memphis Grizzlies
# 25        Washington Wizards
# 26           Detroit Pistons
# 27         Charlotte Hornets
# 28       Cleveland Cavaliers
# 29     Golden State Warriors
# Name: Team_Name, dtype: object

# %%
teams_df.drop(columns=['LEAGUE_ID','MIN_YEAR','MAX_YEAR','CITY','NICKNAME'],inplace=True)

# %%
teams_df
# Out:
#        TEAM_ID  ...               Team_Name
# 0   1610612737  ...           Atlanta Hawks
# 1   1610612738  ...          Boston Celtics
# 2   1610612740  ...    New Orleans Pelicans
# 3   1610612741  ...           Chicago Bulls
# 4   1610612742  ...        Dallas Mavericks
# 5   1610612743  ...          Denver Nuggets
# 6   1610612745  ...         Houston Rockets
# 7   1610612746  ...    Los Angeles Clippers
# 8   1610612747  ...      Los Angeles Lakers
# 9   1610612748  ...              Miami Heat
# 10  1610612749  ...         Milwaukee Bucks
# 11  1610612750  ...  Minnesota Timberwolves
# 12  1610612751  ...           Brooklyn Nets
# 13  1610612752  ...         New York Knicks
# 14  1610612753  ...           Orlando Magic
# 15  1610612754  ...          Indiana Pacers
# 16  1610612755  ...      Philadelphia 76ers
# 17  1610612756  ...            Phoenix Suns
# 18  1610612757  ...  Portland Trail Blazers
# 19  1610612758  ...        Sacramento Kings
# ...

# %%
teams_df.columns
# Out:
# Index(['TEAM_ID', 'ABBREVIATION', 'YEARFOUNDED', 'ARENA', 'ARENACAPACITY',
#        'OWNER', 'GENERALMANAGER', 'HEADCOACH', 'DLEAGUEAFFILIATION',
#        'Team_Name'],
#       dtype='object')

# %%
teams_df.columns = teams_df.columns.str.capitalize()

# %%
teams_df.rename(columns={'Team_id': 'Team_ID','Team_name': 'Team_Name','Yearfounded': 'Year_Founded','Arenacapacity': 'Arena_Capacity','Generalmanager':'General_Manager','Headcoach':'Head_Coach','Dleagueaffiliation': 'DLeague_Affiliation'},inplace=True)

# %%
teams_df.columns
# Out:
# Index(['Team_ID', 'Abbreviation', 'Year_Founded', 'Arena', 'Arena_Capacity',
#        'Owner', 'General_Manager', 'Head_Coach', 'DLeague_Affiliation',
#        'Team_Name'],
#       dtype='object')

# %%
teams_df
# Out:
#        Team_ID  ...               Team_Name
# 0   1610612737  ...           Atlanta Hawks
# 1   1610612738  ...          Boston Celtics
# 2   1610612740  ...    New Orleans Pelicans
# 3   1610612741  ...           Chicago Bulls
# 4   1610612742  ...        Dallas Mavericks
# 5   1610612743  ...          Denver Nuggets
# 6   1610612745  ...         Houston Rockets
# 7   1610612746  ...    Los Angeles Clippers
# 8   1610612747  ...      Los Angeles Lakers
# 9   1610612748  ...              Miami Heat
# 10  1610612749  ...         Milwaukee Bucks
# 11  1610612750  ...  Minnesota Timberwolves
# 12  1610612751  ...           Brooklyn Nets
# 13  1610612752  ...         New York Knicks
# 14  1610612753  ...           Orlando Magic
# 15  1610612754  ...          Indiana Pacers
# 16  1610612755  ...      Philadelphia 76ers
# 17  1610612756  ...            Phoenix Suns
# 18  1610612757  ...  Portland Trail Blazers
# 19  1610612758  ...        Sacramento Kings
# ...

# %%
teams_df.isna().sum()
# Out:
# Team_ID                0
# Abbreviation           0
# Year_Founded           0
# Arena                  0
# Arena_Capacity         4
# Owner                  0
# General_Manager        0
# Head_Coach             0
# DLeague_Affiliation    0
# Team_Name              0
# dtype: int64

# %%
teams_df.fillna(0,inplace=True)
teams_df.shape
# Out:
# (30, 10)

# %%
teams_df.dtypes
# Out:
# Team_ID                  int64
# Abbreviation            object
# Year_Founded             int64
# Arena                   object
# Arena_Capacity         float64
# Owner                   object
# General_Manager         object
# Head_Coach              object
# DLeague_Affiliation     object
# Team_Name               object
# dtype: object

# %%
teams_df = teams_df.astype({'Arena_Capacity' : 'int'})

# %%
teams_df
# Out:
#        Team_ID  ...               Team_Name
# 0   1610612737  ...           Atlanta Hawks
# 1   1610612738  ...          Boston Celtics
# 2   1610612740  ...    New Orleans Pelicans
# 3   1610612741  ...           Chicago Bulls
# 4   1610612742  ...        Dallas Mavericks
# 5   1610612743  ...          Denver Nuggets
# 6   1610612745  ...         Houston Rockets
# 7   1610612746  ...    Los Angeles Clippers
# 8   1610612747  ...      Los Angeles Lakers
# 9   1610612748  ...              Miami Heat
# 10  1610612749  ...         Milwaukee Bucks
# 11  1610612750  ...  Minnesota Timberwolves
# 12  1610612751  ...           Brooklyn Nets
# 13  1610612752  ...         New York Knicks
# 14  1610612753  ...           Orlando Magic
# 15  1610612754  ...          Indiana Pacers
# 16  1610612755  ...      Philadelphia 76ers
# 17  1610612756  ...            Phoenix Suns
# 18  1610612757  ...  Portland Trail Blazers
# 19  1610612758  ...        Sacramento Kings
# ...

# %%
teams_df.dtypes
# Out:
# Team_ID                 int64
# Abbreviation           object
# Year_Founded            int64
# Arena                  object
# Arena_Capacity          int64
# Owner                  object
# General_Manager        object
# Head_Coach             object
# DLeague_Affiliation    object
# Team_Name              object
# dtype: object

# %%
teams_df.to_csv('Teams.csv',index=False)
from google.colab import files
files.download("Teams.csv")

# %%
team_stats = pd.read_csv('/content/nba_team_stats_00_to_18.csv')
team_stats
# Out:
#      Unnamed: 0                 TEAM  GP   W  ...    PF   PFD  +/-   SEASON
# 0             0        Atlanta Hawks  82  29  ...  23.6  22.2 -6.0  2018-19
# 1             1       Boston Celtics  82  49  ...  20.4  19.5  4.4  2018-19
# 2             2        Brooklyn Nets  82  42  ...  21.5  22.0 -0.1  2018-19
# 3             3    Charlotte Hornets  82  39  ...  18.9  20.6 -1.1  2018-19
# 4             4        Chicago Bulls  82  22  ...  20.3  18.7 -8.4  2018-19
# ..          ...                  ...  ..  ..  ...   ...   ...  ...      ...
# 561         561  Seattle SuperSonics  82  44  ...  21.1   0.1  0.0  2000-01
# 562         562      Toronto Raptors  82  47  ...  21.3   0.1  2.3  2000-01
# 563         563            Utah Jazz  82  53  ...  25.7   0.1  4.7  2000-01
# 564         564  Vancouver Grizzlies  82  23  ...  21.1   0.1 -5.7  2000-01
# 565         565   Washington Wizards  82  19  ...  23.3   0.1 -6.7  2000-01
#
# [566 rows x 29 columns]

# %%
team_stats.columns
# Out:
# Index(['Unnamed: 0', 'TEAM', 'GP', 'W', 'L', 'WIN%', 'MIN', 'PTS', 'FGM',
#        'FGA', 'FG%', '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB',
#        'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', '+/-',
#        'SEASON'],
#       dtype='object')

# %%
team_stats.drop(columns=['Unnamed: 0'],inplace=True)

# %%
team_stats.columns
# Out:
# Index(['TEAM', 'GP', 'W', 'L', 'WIN%', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%',
#        '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST',
#        'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', '+/-', 'SEASON'],
#       dtype='object')

# %%
team_stats.rename(columns={'WIN%':'Win_Percentage','FG%':'FG_Percentage','3P%':'3P_Percentage','FT%':'FT_Percentage','+/-':'Plus_Minus','PTS':'Pts','MIN':'Min','SEASON': 'Season'},inplace=True)

# %%
team_stats.columns
# Out:
# Index(['TEAM', 'GP', 'W', 'L', 'Win_Percentage', 'Min', 'Pts', 'FGM', 'FGA',
#        'FG_Percentage', '3PM', '3PA', '3P_Percentage', 'FTM', 'FTA',
#        'FT_Percentage', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK',
#        'BLKA', 'PF', 'PFD', 'Plus_Minus', 'Season'],
#       dtype='object')

# %%
teams_df1 = teams_df[['Team_ID','Team_Name']]
teams_df1
# Out:
#        Team_ID               Team_Name
# 0   1610612737           Atlanta Hawks
# 1   1610612738          Boston Celtics
# 2   1610612740    New Orleans Pelicans
# 3   1610612741           Chicago Bulls
# 4   1610612742        Dallas Mavericks
# 5   1610612743          Denver Nuggets
# 6   1610612745         Houston Rockets
# 7   1610612746    Los Angeles Clippers
# 8   1610612747      Los Angeles Lakers
# 9   1610612748              Miami Heat
# 10  1610612749         Milwaukee Bucks
# 11  1610612750  Minnesota Timberwolves
# 12  1610612751           Brooklyn Nets
# 13  1610612752         New York Knicks
# 14  1610612753           Orlando Magic
# 15  1610612754          Indiana Pacers
# 16  1610612755      Philadelphia 76ers
# 17  1610612756            Phoenix Suns
# 18  1610612757  Portland Trail Blazers
# 19  1610612758        Sacramento Kings
# 20  1610612759       San Antonio Spurs
# 21  1610612760   Oklahoma City Thunder
# 22  1610612761         Toronto Raptors
# ...

# %%
result = teams_df1.merge(team_stats,left_on="Team_Name",right_on="TEAM")

# %%
result
# Out:
#         Team_ID              Team_Name  ... Plus_Minus   Season
# 0    1610612737          Atlanta Hawks  ...       -6.0  2018-19
# 1    1610612737          Atlanta Hawks  ...       -5.5  2017-18
# 2    1610612737          Atlanta Hawks  ...       -0.9  2016-17
# 3    1610612737          Atlanta Hawks  ...        3.6  2015-16
# 4    1610612737          Atlanta Hawks  ...        5.4  2014-15
# ..          ...                    ...  ...        ...      ...
# 515  1610612744  Golden State Warriors  ...       -2.2  2004-05
# 516  1610612744  Golden State Warriors  ...       -0.7  2003-04
# 517  1610612744  Golden State Warriors  ...       -1.1  2002-03
# 518  1610612744  Golden State Warriors  ...       -5.4  2001-02
# 519  1610612744  Golden State Warriors  ...       -9.0  2000-01
#
# [520 rows x 30 columns]

# %%
result.drop(columns=['TEAM','Team_Name'],inplace=True)

# %%
result
# Out:
#         Team_ID  GP   W   L  ...    PF   PFD  Plus_Minus   Season
# 0    1610612737  82  29  53  ...  23.6  22.2        -6.0  2018-19
# 1    1610612737  82  24  58  ...  19.6  20.3        -5.5  2017-18
# 2    1610612737  82  43  39  ...  18.2  21.6        -0.9  2016-17
# 3    1610612737  82  48  34  ...  19.1  18.3         3.6  2015-16
# 4    1610612737  82  60  22  ...  17.8  19.6         5.4  2014-15
# ..          ...  ..  ..  ..  ...   ...   ...         ...      ...
# 515  1610612744  82  34  48  ...  22.4   0.0        -2.2  2004-05
# 516  1610612744  82  37  45  ...  20.6   0.0        -0.7  2003-04
# 517  1610612744  82  38  44  ...  21.8   0.0        -1.1  2002-03
# 518  1610612744  82  21  61  ...  23.0   0.2        -5.4  2001-02
# 519  1610612744  82  17  65  ...  21.1   0.1        -9.0  2000-01
#
# [520 rows x 28 columns]

# %%
result['Season'] = result['Season'].apply(lambda x : x.split("-")[0])

# %%
result
# Out:
#         Team_ID  GP   W   L  ...    PF   PFD  Plus_Minus  Season
# 0    1610612737  82  29  53  ...  23.6  22.2        -6.0    2018
# 1    1610612737  82  24  58  ...  19.6  20.3        -5.5    2017
# 2    1610612737  82  43  39  ...  18.2  21.6        -0.9    2016
# 3    1610612737  82  48  34  ...  19.1  18.3         3.6    2015
# 4    1610612737  82  60  22  ...  17.8  19.6         5.4    2014
# ..          ...  ..  ..  ..  ...   ...   ...         ...     ...
# 515  1610612744  82  34  48  ...  22.4   0.0        -2.2    2004
# 516  1610612744  82  37  45  ...  20.6   0.0        -0.7    2003
# 517  1610612744  82  38  44  ...  21.8   0.0        -1.1    2002
# 518  1610612744  82  21  61  ...  23.0   0.2        -5.4    2001
# 519  1610612744  82  17  65  ...  21.1   0.1        -9.0    2000
#
# [520 rows x 28 columns]

# %%
result['Season'].value_counts()
# Out:
# 2014    30
# 2015    29
# 2017    29
# 2013    29
# 2018    29
# 2016    29
# 2012    28
# 2009    27
# 2001    27
# 2008    27
# 2011    27
# 2010    27
# 2005    26
# 2000    26
# 2004    26
# 2002    26
# 2006    26
# 2003    26
# 2007    26
# Name: Season, dtype: int64

# %%
result = result.astype({'Season' : 'int'})

# %%
result.dtypes
# Out:
# Team_ID             int64
# GP                  int64
# W                   int64
# L                   int64
# Win_Percentage    float64
# Min               float64
# Pts               float64
# FGM               float64
# FGA               float64
# FG_Percentage     float64
# 3PM               float64
# 3PA               float64
# 3P_Percentage     float64
# FTM               float64
# FTA               float64
# FT_Percentage     float64
# OREB              float64
# DREB              float64
# REB               float64
# AST               float64
# TOV               float64
# STL               float64
# BLK               float64
# BLKA              float64
# PF                float64
# PFD               float64
# Plus_Minus        float64
# Season              int64
# dtype: object

# %%
teams_df.dtypes
# Out:
# Team_ID                 int64
# Abbreviation           object
# Year_Founded            int64
# Arena                  object
# Arena_Capacity          int64
# Owner                  object
# General_Manager        object
# Head_Coach             object
# DLeague_Affiliation    object
# Team_Name              object
# dtype: object

# %%
result.to_csv('Team_stats.csv',index=False)
from google.colab import files
files.download("Team_stats.csv")
